# %% [raw]
# Auf Divided Skills Labelschema ausgelegt.
# Bearbeitet doccanos CV-weisen Datensatz und passt Label an, um Einheitlichkeit zu gewährleisten.
# Die ausgegebene Datei kann mit "JsonToSpaCy_Edited.ipynb" in spacy-Format umgewandelt werden.
# Weiter unten werden genauere Informationen zu den Labeln berechnet.

# %%
# doccano.json einlesen
import json
import spacy
from spacy.tokens import DocBin

# ----------------------------------
# ------------ Options: ------------
# ----------------------------------

# sortiert Label anhand der shouldBe-Listen wenn nötig um
doRearrange = True
# exportiert die entstandenen Daten als jsonl-Datei
doExport = False
# zeigt im searchText-Bereich auch den Kontext an, in dem die gesuchten Begriffe stehen
showContext = False
# printet Labelanzahlen 
printCounter = False
# maximale Anzahl von Wörtern um die Spangrenzen (Labelgrenzen) verschoben werden können
# Wird benötigt, um Fehler zu vermeiden
maxCounter = 30

# Nummer des Datensatzes, der bearbeitet werden soll
modelNumber = "3"    

# muss komplett in kleinbuchstaben sein
searchTexts = [
        "TextToSearch",
    ] 


# ------------------------------------
# ---- Listen zur Labelanpassung: ----
# ------------------------------------

shouldBeSkill = [
    'alv', 'applikation management', 'berichte', 'co', 
    'organisationsmanagement', 'reporting', 'report', 'reports', 'abrechnungssteuerung', 
    'aufbauorganisation', 'datenmodellierung', 'golive support', 
    'qualitätssicherung', 'qualitätsqueck', 'prototyping', 'servicemanagement', 
    'opportunity- und vertragsmanagement', 'veranstaltungsmanagement', 'testmanagement', 
    'testkonzepterstellung', 'testkonzeption', 'testmanagement', 'abnahmetests', 
    'aufwandsschätzung', 'aufwandsschätzungen', 'abrechnungsvergleich', 
    'anforderungsanalyse', 'anforderungserhebung', 'business process integration', 
    'finanzreporting', 'geschäftspartnerkonsolidierung', 'personalabrechnungsverfahren', 
    'ressourcenplanung', 'controlling', 'reklamationsmanagement', 'besuchsmanagement',
    'geschäftsprozessanalyse', 'anforderungsaufnahme', 'anwendungsentwicklung',
    'datenmigration', 'vertriebsprozesse','go-live-support', 'planungs–systems',
    'sap-systeme', 'datenbankdesign', 'powershell-skripting', 'powershell-/json-skripting',
    'proof-of-concept', 'arbeitsprozessanalyse', 'fachkonzept', 'produktivsetzung',
    'schnittstellen', 'userstories', 'fehleranalyse', 'project \nmanagement', 'sepa-umstellung',
    'sepa-überweisung', 'einführungsprojekt', 'exchange', 'feinkonzept', 'release dokumentation',
    'vertriebsplanung', 'kostenplanung', 'kosten-planungslösung', 'besuchsplanung und -durchführung',
    'planungsfunktionen', 'migrationsplan', 'migrationsplane', 'rolloutplanung',
    'test-planung, -durchführung, -dokumentation', 'technische konzepterstellung', 
    'reporterstellung', 'konzepterstellung', 'testunterstützung', 'anwendungsunterstützung',
    'technischen 	vertriebsunterstützung', 'entwicklungsunterstützung', 'programmierunterstützung',
    'backups', 'program management', "software auswahl","software-updates",
    "softwareanalysen","softwareauswahl","softwaretests","softwareupdates",
    "ticketaufbereitung","ticketbearbeitung","applikationsentwicklung","auditbegleitung",
    "bu übergabe","bu übergaben","data warehouse design","datenaustausch","entwicklungsbegleitung",
    "going live","kostenstellenverantwortung","lohnkonten- und stammdatenmigration","lösungsdesign",
    "lösungs-design","parallelabrechnung","patch-level upgrades","patch-level upgrades",
    "roll out management","rolloutsteuerung","sap bw plattform migration","sw- und produktentwicklungen",
    "sales-reporting","stabilisierungsmaßnahmen","strategieberatung","strategieempfehlungen",
    "transitionmangement","wissenskonsolidierung","wissenstransfer","workflowimplementierung",
    "multidimensionalen und relationalen analyse- und berichtsstrukturen","lieferantenbetreuung",
    "produktivexport","produktivmigration","produktivbetreuung","produktivbegleitung",
    "produktivbetriebe","programmleitung", 'produktivbetriebes', 'active directory',
    'grobkonzepten', 'sap bw', 'performance optimierung'
]

shouldBeSkillIfContains = [
    "project", "projekt", "prozess", "process", "system", "level support","level-support"
]

shouldBeActivity = [
    'administration', 'auswertungen', 'analyse', 'test', 'testing', 'agile testing', 'design', 
    'simulation','betreuung', 'hosting', 'umsetzung', 'erweiterungen', 'support prozesses', 
    'inbetriebnahme', 'konsolidierung', 'vertrieb', 'vertriebs', 'vorstudie', 'programmierkenntnisse', 
    'verschlüsselung', 'consulting', 'planung', 'planungen', 'strategische planung',
    'operative und strategische planung', 'einplanung', 'geplant', "planen", "lncentive planung",
    "softwareentwicklung", 'ablösung', 'anbindung', 'dashboarding', 'recoverys', 'aufbau',
    'rollierende planung', 'training', 'untersuchungen', 'software entwicklung', 'enhancements',
    'it strategie', 'it strategien', 'it-strategien', 'monitorings'
]

shouldBeBranche = [
    "öffentliche verwaltung"
]


shouldHaveNoLabel = [
    'datenqualität', 'datenqualität check', 'portal', 'programmiersprachen', 'prüfzeugnis', 
    'genehmigung', 'tickets', ')', 'project', 'projektdokumente', 'projektdokumenten',
    'prozessfehlern', 'dokumenten', 'briefschreibung','entwicklungsumfeld','erfahrungsaustausch',
    'führungserfahrung', 'einbeziehung'
]


# -----------------------------------
# ----------- Funktionen: -----------
# -----------------------------------

def importData(modelNumber):
    cvList = []
    with open("./corpus/Modell_{}/data.jsonl".format(modelNumber), 'r') as f:
        for cv in f:
            currentCV = json.loads(cv)
            cvList.append(currentCV)   
    return cvList
  

def exportData(dicts, modelNumber, cvDicts):
    try:
        for cv in cvDicts:
            spacy.training.offsets_to_biluo_tags(nlp.make_doc(cv['text']), cv['label'])
        fileName = './corpus/Modell_{}/editedData.jsonl'.format(modelNumber)
        with open(fileName, 'w', encoding='utf-8') as f:
            json.dump(dicts, f, ensure_ascii=False)
    except:
        print("ERROR WHILE EXPORTING")
        

"""
Benötigt um Span-/Labelgrenzen anzupassen, sodass sie den spaCy-Standards entsprechen.
Wird das nicht gemacht, kann es später zu Fehlern kommen.
Möglicherweise fallen hierdurch Label weg. 
Bspw. kann "Java-Programmierung" in spaCy nur als ganzes gelabelt werden.
"""
def adjustSpanBoundaries(start, end, label, maxCounter):
    span = doc.char_span(start, end, label=label)
    # wird True gesetzt, wenn es trotz verschieben Labelgrenzen zu Fehlern kommt
    boundaryError = False

    newEnd = end
    counter = 0;
    #verschiebt die Grenze nach hinten, solange der span ungültig ist
    while span == None and not counter > maxCounter:
        counter = counter + 1
        newEnd = newEnd + 1
        span = doc.char_span(start, newEnd, label=label)

    # geht hier rein, falls der span immer noch ungültig ist
    if span == None:
        newEnd = end
        counter = 0;
        # setzt die Spangrenze zurück und verschiebt sie diesmal nach vorne, solange der span ungültig ist
        while span == None and not counter > maxCounter:
            counter = counter + 1
            start = start - 1
            span = doc.char_span(start, end, label=label)
        # gibt Fehler zurück, sollte der span immer noch ungültig sein
        if span == None:
            boundaryError = True

    return boundaryError, span, start, newEnd 
                
"""
Passt Label basierend auf den entsprechenden Listen an, um Einheitlichkeit zu gewährleisten.
"""
def rearrangeLabels(span, spanStart, spanEnd, label):
    spanText = span.text.lower()
    deleteThisLabel = False
    if spanText in shouldHaveNoLabel:
        #print("---- DELETED LABEL: ", span.text, " ----") 
        deleteThisLabel = True
    elif label == "Tätigkeit" and spanText in shouldBeSkill:
        #print("---- CHANGED LABEL TO Skill: ", span.text, " ----") 
        span = doc.char_span(spanStart, spanEnd, label="Skill")
        label = "Skill"                 
    elif label == "Skill" and spanText in shouldBeActivity:
        #print("---- CHANGED LABEL TO Tätigkeit: ", span.text, " ----") 
        span = doc.char_span(spanStart, spanEnd, label="Tätigkeit")
        label = "Tätigkeit"
    elif not label == "Branche" and spanText in shouldBeBranche:
        #print("---- CHANGED LABEL TO Branche: ", span.text, " ----") 
        span = doc.char_span(spanStart, spanEnd, label="Branche")
        label = "Branche"
    elif label == "Tätigkeit":
        for element in (element for element in shouldBeSkillIfContains if element in spanText):
            #print("---- CHANGED LABEL TO Skill: ", span.text, " ----") 
            span = doc.char_span(spanStart, spanEnd, label="Skill")
            label = "Skill"  
            
    return span, label, deleteThisLabel
                        
"""
Prüft, ob der aktuelle Span sich mit keinem anderen überlappt, da spaCy damit nicht umgehen kann.
Gibt einen entsprechenden boolean zurück.
"""      
def checkForOverlap(spanStart, spanEnd, labels):
    foundOverlap = False
    for otherStart, otherEnd, _ in labels:
        if otherStart == spanStart and otherEnd == spanEnd:
            foundOverlap = True
        elif spanStart < otherEnd and spanEnd > otherStart:
            foundOverlap = True
    return foundOverlap

"""
Printet alle gefundenen Spans, in denen einer der übergebenen searchTexts vorkommt
"""
def searchForTokens(searchTexts, span, allreadyFound, showContext):
    spanText = span.text.lower()
    for searchText in searchTexts: 
        if searchText in spanText and not ("{} - LABEL: {}".format(spanText, span.label_) in allreadyFound):
            allreadyFound.append("{} - LABEL: {}".format(spanText, span.label_))
            if showContext:
                print("---- INCLUDES", searchText,": ", span.text, "; LABEL: ", label, " ----")
                contextLen = 1
                if (span.start - contextLen >= 0):
                    span.start = span.start - contextLen
                else:
                    span.start = 0                           
                if (span.end + contextLen <= len(doc)):
                    span.end = span.end + contextLen
                else:
                    span.end = len(doc)
                print("    ---- CONTEXT: ", span.text, " ----")
                span.start = span.start + contextLen
                span.end = span.end - contextLen  
            else:
                print("---- INCLUDES", searchText,": ", span.text, "\n       LABEL: ", label, " ----")   


# -----------------------------------
# -------------- Main: --------------
# -----------------------------------

# leeres neues Modell erstellen
nlp = spacy.blank("de")
cvList = importData(modelNumber)

# Arrays mit allen vergebenen Labeln
activities = []
skills = []
rollen = []
branchen = []

allreadyFound = []
# zählt wie oft die einzelnen Label vorkommen
labelCounter = []

# speichert die CVs mit den bearbeiteten Labels
cvDicts = []
dicts = {"CVs": cvDicts}

# geht jedes Datenelement (hier CV) durch und überprüft alle Label
for cv in cvList:
    try:
        text = cv['data']
    except:
        text = cv['text']
    annotations = cv['label']
    
    doc = nlp(text)
    
    counterSkills = 0
    counterActivities = 0
    counterRolle = 0
    counterBranche = 0
    
    # packt angepasste Daten in ein dictionary, das aufgebaut ist, wie die zu exportierende json-Datei
    labels = []
    cvDict = {
      "text": text,
      "label": labels
    }
    
    # geht alle Label durch
    for annotation in annotations:
        label = annotation[2]
        boundaryError, span, spanStart, spanEnd = adjustSpanBoundaries(int(annotation[0]), int(annotation[1]), label, maxCounter)
           
        # bei boundaryError wird das Label übersprungen und fällt damit weg
        if not boundaryError:
            if doRearrange:
                span, label, deleteThisLabel = rearrangeLabels(span, spanStart, spanEnd, label)
                if deleteThisLabel:
                    continue
                      
            searchForTokens(searchTexts, span, allreadyFound, showContext)
            
            # sortiert sich überlappende Label aus  
            foundOverlap = checkForOverlap(spanStart, spanEnd, labels)
                
            # speichert Label, sofern es sich mit keinem anderen überschneidet
            if not foundOverlap:
                labels.append([spanStart, spanEnd, label])
                # zählt counter hoch
                if label == "Tätigkeit":
                    activities.append(span.text)
                    counterActivities = counterActivities + 1
                elif label == "Skill":
                    skills.append(span.text)  
                    counterSkills = counterSkills + 1
                elif label == "Branche": 
                    branchen.append(span.text)
                    counterBranche = counterBranche + 1
                elif label == "Rolle": 
                    rollen.append(span.text)
                    counterRolle = counterRolle + 1
                
    cvDicts.append(cvDict)
    labelCounter.append({
        "Tätigkeiten": counterActivities, 
        "Skills": counterSkills, 
        "Branchen": counterBranche, 
        "Rollen": counterRolle, 
        "Gesamt": (counterActivities+counterSkills+counterBranche+counterRolle)
    })
    
if doExport:
    exportData(dicts, modelNumber, cvDicts)

# %%
# Berechnet Infos zur Labelverteilung 
# maximales, minimales und durchschnittliches Labelvorkommen in den einzelnen CVs

ActivityDiv = {"abs": 0,"max": 0,"min": 999999,"average": 0}
SkillDiv    = {"abs": 0,"max": 0,"min": 999999,"average": 0}
BrancheDiv  = {"abs": 0,"max": 0,"min": 999999,"average": 0}
RolleDiv    = {"abs": 0,"max": 0,"min": 999999,"average": 0}
GesamtDiv   = {"abs": 0,"max": 0,"min": 999999,"average": 0}

for cv in labelCounter:
    if cv["Tätigkeiten"] > ActivityDiv["max"]:
        ActivityDiv["max"] = cv["Tätigkeiten"]
    elif cv["Tätigkeiten"] < ActivityDiv["min"]:
        ActivityDiv["min"] = cv["Tätigkeiten"]
    ActivityDiv["abs"] = ActivityDiv["abs"] + cv["Tätigkeiten"]
    if cv["Skills"] > SkillDiv["max"]:
        SkillDiv["max"] = cv["Skills"]
    elif cv["Skills"] < SkillDiv["min"]:
        SkillDiv["min"] = cv["Skills"]
    SkillDiv["abs"] = SkillDiv["abs"] + cv["Skills"]
    if cv["Branchen"] > BrancheDiv["max"]:
        BrancheDiv["max"] = cv["Branchen"]
    elif cv["Branchen"] < BrancheDiv["min"]:
        BrancheDiv["min"] = cv["Branchen"]
    BrancheDiv["abs"] = BrancheDiv["abs"] + cv["Branchen"]
    if cv["Rollen"] > RolleDiv["max"]:
        RolleDiv["max"] = cv["Rollen"]
    elif cv["Rollen"] < RolleDiv["min"]:
        RolleDiv["min"] = cv["Rollen"]
    RolleDiv["abs"] = RolleDiv["abs"] + cv["Rollen"]
    if cv["Gesamt"] > GesamtDiv["max"]:
        GesamtDiv["max"] = cv["Gesamt"]
    elif cv["Gesamt"] < GesamtDiv["min"]:
        GesamtDiv["min"] = cv["Gesamt"]
    GesamtDiv["abs"] = GesamtDiv["abs"] + cv["Gesamt"]
    
ActivityDiv["average"] = round(ActivityDiv["abs"] / len(labelCounter), 2)
SkillDiv["average"]    = round(SkillDiv["abs"] / len(labelCounter), 2)
BrancheDiv["average"]  = round(BrancheDiv["abs"] / len(labelCounter), 2)
RolleDiv["average"]    = round(RolleDiv["abs"] / len(labelCounter), 2)
GesamtDiv["average"]   = round(GesamtDiv["abs"] / len(labelCounter), 2)

print("Datenmenge:", len(labelCounter))
print("Tätigkeiten:", ActivityDiv)
print("Skills:     ", SkillDiv)
print("Branchen:   ", BrancheDiv)
print("Rollen:     ", RolleDiv)
print("Gesamt:     ", GesamtDiv)
# Out:
# Datenmenge: 20
# Tätigkeiten: {'abs': 1341, 'max': 261, 'min': 11, 'average': 67.05}
# Skills:      {'abs': 2373, 'max': 460, 'min': 22, 'average': 118.65}
# Branchen:    {'abs': 295, 'max': 40, 'min': 3, 'average': 14.75}
# Rollen:      {'abs': 311, 'max': 59, 'min': 2, 'average': 15.55}
# Gesamt:      {'abs': 4320, 'max': 707, 'min': 43, 'average': 216.0}

# %%
# Printet alle aktuell gelabelten Elemente und wie oft sie gelabelt wurden nach ihrem Label sortiert.
# Zeigt außerdem Wörter an, die sowohl als Skill als auch als Tätigkeit gelabelt wurden.
#  Nutzt das distance-Package, um dabei auch ähnliche Wörter anzuzeigen.

# printet die Ergebnisse
import distance 

# damit jeder Skill nur einmal in der Liste ist
skills.sort()
activities.sort()
rollen.sort()
branchen.sort()

#Erstellt dicts, um zu zählen, wie oft jede Wortsequenz gelabelt wurde
setList = list(set(skills)) 
skillDict = {i:skills.count(i) for i in setList}
setList = list(set(activities)) 
activitiesDict = {i:activities.count(i) for i in setList}
setList = list(set(rollen)) 
rollenDict = {i:rollen.count(i) for i in setList}
setList = list(set(branchen)) 
branchenDict = {i:branchen.count(i) for i in setList}
skillsWithCount = []
activitiesWithCount = []
rollenWithCount = []
branchenWithCount = []


for entry in skillDict:
    skillsWithCount.append("{} - ({}x)".format(entry, skillDict.get(entry)))  
for entry in activitiesDict:
    activitiesWithCount.append("{} - ({}x)".format(entry, activitiesDict.get(entry)))   
for entry in rollenDict:
    rollenWithCount.append("{} - ({}x)".format(entry, rollenDict.get(entry))) 
for entry in branchenDict:
    branchenWithCount.append("{} - ({}x)".format(entry, branchenDict.get(entry))) 

#Sorgt dafür, dass jeder Eintrag nur einmal in den Listen vorkommt
activities = list(dict.fromkeys(activities))
skills = list(dict.fromkeys(skills)) 
rollen = list(dict.fromkeys(rollen)) 
branchen = list(dict.fromkeys(branchen)) 
    
skillsWithCount.sort()
activitiesWithCount.sort()
rollenWithCount.sort()
branchenWithCount.sort()

print("Anz unique Skills: ", len(skillsWithCount))
print("Anz unique Activities: ", len(activitiesWithCount))
print("Anz unique Rollen: ", len(rollenWithCount))

# Printet Wörter, die sowohl als Skill als auch als Tätigkeit vorkommen
printDoubles = True #True #False
if printDoubles:
    print("\n=> Kommt als Skill und als Tätigkeit vor: ")
    for skill in skills:
        for activity in activities:
            if skill == activity:
                print (skill)
            elif abs(len(activity) - len(skill)) < 3:
                maxLevDist = int(len(activity)/5)
                if distance.levenshtein(skill, activity) <= maxLevDist:
                    print("Similar: ", skill, " -- ", activity)

print("\n ---------------------------------------------------------------------  \n")
print("=> Skills: ")
for skill in skillsWithCount:
    print(skill)
    
print("\n ---------------------------------------------------------------------  \n")
print("=> Tätigkeiten: ")
for activity in activitiesWithCount:
    print(activity)
        
print("\n ---------------------------------------------------------------------  \n")
print("=> Rollen: ")
for rolle in rollenWithCount:
    print(rolle)
       
print("\n ---------------------------------------------------------------------  \n")
print("=> Branchen: ")
for branche in branchenWithCount:
    print(branche)
# Out:
# Anz unique Skills:  1219
# Anz unique Activities:  346
# Anz unique Rollen:  107
#
# => Kommt als Skill und als Tätigkeit vor:
#
#  ---------------------------------------------------------------------
#
# => Skills:
# 1st Level Support - (1x)
# 1st, 2nd und 3rd Level Support - (2x)
# 1st-Level, 2nd-Level-Support - (1x)
# 2. Level Support - (2x)
# 2nd oder 3rd Level Support - (1x)
# 2nd-Level-Support - (1x)
# ABAP - (30x)
# ABAP 4 - (1x)
# ABAP OO - (4x)
# ABAP Objects - (1x)
# ABAP-Klassen und -Interfaces - (1x)
# ABAP-Routinen - (1x)
# ABAP/4 - (6x)
# ABAP/OO - (1x)
# AI - (1x)
# ALV - (2x)
# AMDP - (1x)
# AS/400 - (1x)
# AVAYA - (2x)
# Ablieferungsplanung - (1x)
# Ablieferungsverzeichnissen - (1x)
# Abnahmetests - (1x)
# Abrechnung - (6x)
# Abrechnung Deutschland - (1x)
# Abrechnung Österreich - (1x)
# Abrechnungssteuerung - (7x)
# Abrechnungsvergleich - (2x)
# Absatzplanung - (1x)
# Access - (1x)
# Access Management - (1x)
# Active Directory - (2x)
# Add-Ons - (2x)
# Adobe Analytics - (1x)
# Adobe Creative Suite - (1x)
# Adobe LiveCycle Designer - (3x)
# Advanced Analysis Reports - (1x)
# AfO - (1x)
# Afa - (1x)
# After Go-Life Betreuung - (1x)
# Aggregaten - (1x)
# Aggregationsebenen - (2x)
# Aggregationstabellen - (1x)
# Analyseberechtigungen - (2x)
# Analyseprojekt - (1x)
# Analysis For Office - (4x)
# Analysis for Office - (5x)
# Analytics - (6x)
# Anaplan Connected Planning - (1x)
# Anaplan Model - (1x)
# Android - (1x)
# Android-Mobilgeräte - (1x)
# Anforderungsanalyse - (8x)
# Anforderungserhebung - (2x)
# Anforderungskatalog - (1x)
# Anforderungskatalogs - (1x)
# Anwendungsentwicklung - (2x)
# Applikation Management - (3x)
# Applikationsbetreuung - (1x)
# Applikationsentwicklung - (1x)
# Applikationslogik - (1x)
# Applikationsserver - (1x)
# Arbeitsmappen - (4x)
# Arbeitszeitpläne - (1x)
# Arbeitszeitplänen - (4x)
# Architektur - (3x)
# Architekturen - (3x)
# Archivierungskonzept - (2x)
# Archivierungskonzepte - (1x)
# Artificial Intelligence - (1x)
# Astaro - (1x)
# Aufbauorganisation - (3x)
# Auftragsbestandsermittlung - (1x)
# Auftragsdatenbank - (1x)
# Aufwandsschätzung - (3x)
# Aufwandsschätzungen - (1x)
# Ausschreibungen - (1x)
# Axure RP - (1x)
# BA - (1x)
# BAPI Funktionsbausteinen - (1x)
# BAPIs - (1x)
# BAV - (3x)
# BEx Analyzer - (1x)
# BEx Queries - (4x)
# BEx Query Designer - (2x)
# BEx Tools - (12x)
# BI - (4x)
# BI Systems - (2x)
# BIRT Engine - (1x)
# BIRT Report Engine - (1x)
# BIRT Reportengine - (1x)
# BO - (3x)
# BPC - (1x)
# BPMN - (1x)
# BRF+ Regeln - (1x)
# BSP - (1x)
# BSP-Applikationen - (1x)
# BW - (5x)
# BW 7.4 on HANA - (2x)
# BW 7.5 on HANA - (1x)
# BW Berechtigungen - (1x)
# BW Modelle - (1x)
# BW Systems - (1x)
# BW on HANA - (1x)
# BW on HANA Datenmodelle - (1x)
# BW on HANA System (7.5) - (1x)
# BW on HANA System - (1x)
# BW-Berechtigungsrollen - (1x)
# BW-IP - (3x)
# BW-Systeme - (1x)
# Backend - (4x)
# Backlogmanagement - (1x)
# Backlogrefinement - (1x)
# Backup Systems - (1x)
# Balanced Scorecarding - (1x)
# BatchMan-Jobs - (1x)
# Benutzerberichtigungen - (1x)
# Benutzerhandbuch - (1x)
# Benutzerverwaltung - (5x)
# Berechtigungen - (17x)
# Berechtigungsanforderungen - (2x)
# Berechtigungsfehlern - (2x)
# Berechtigungskonzept - (7x)
# Berechtigungskonzepten - (1x)
# Berechtigungskonzeptes - (3x)
# Berechtigungskonzepts - (1x)
# Berechtigungsrahmenkonzept - (1x)
# Berechtigungsrahmenkonzeptes - (1x)
# Berechtigungsrisiken - (1x)
# Berechtigungsrollen - (5x)
# Berechtigungsverwaltung - (1x)
# Berechtigungswesen - (1x)
# Berichte - (5x)
# Berichten - (1x)
# Berichterstattung - (3x)
# Berichtsanforderungen - (2x)
# Berichtssystems - (2x)
# Berichtswesens - (1x)
# Best Practice SAP - (1x)
# Bestellungskommissionierung - (1x)
# Besuchsmanagement - (1x)
# Besuchsplanung und -durchführung - (1x)
# Betreuungsprozesse - (1x)
# Betriebsmodells - (2x)
# Bewertungsanforderungen - (1x)
# Bex Analyzer - (1x)
# Bex-Tools - (1x)
# Bilanz - (1x)
# Bilanz Konten - (1x)
# Bilanz Planung - (1x)
# Bilanzreporting - (4x)
# Buchungssysteme - (1x)
# Budget Planung - (1x)
# Budgets - (1x)
# Budgetverantwortung - (6x)
# Building Blocks - (1x)
# Business Analyse - (3x)
# Business Blueprint - (20x)
# Business Blueprints - (1x)
# Business Intelligence - (6x)
# Business Intelligence Applikation - (1x)
# Business Logiken - (1x)
# Business Planning - (1x)
# Business Process Integration - (1x)
# Business Suite on HANA - (3x)
# Business Warehouse - (1x)
# Businessrollen-Katalog - (1x)
# C - (2x)
# C# - (3x)
# C++ - (3x)
# C4C - (3x)
# C4C-Opportunity - (1x)
# C4C50 - (1x)
# CDS Views - (1x)
# CDS views - (1x)
# CMLDOCUMNT - (1x)
# CO - (8x)
# CO Kontenmodell - (2x)
# CO-/COPA-Reporting - (1x)
# CO-OM - (1x)
# CO-PA - (1x)
# CO-PA-Daten - (1x)
# COLORADO SAP HCM - (1x)
# CO_ITEM - (1x)
# CRISP-DM - (1x)
# CRM Mobile 4.0 - (1x)
# CRM oP - (1x)
# CRMs - (2x)
# CSS - (5x)
# Calculation Views - (4x)
# Cash-Flow - (1x)
# Change Management - (3x)
# Change Request - (3x)
# Change Requests - (1x)
# Change requests - (1x)
# Chargenrückverfolgung - (1x)
# Chemische Industrie - (1x)
# Ciber - (1x)
# Cisico - (1x)
# Citrix - (2x)
# Cloud for Sales - (1x)
# Cognos 11 - (1x)
# Cognos Interfaces - (1x)
# Compliance Now - (1x)
# Compliance Tools - (1x)
# ComplianceNow - (1x)
# Contentadministration - (1x)
# Contolling - (1x)
# Controlling - (5x)
# Core Designs - (1x)
# Corporate Information Systems - (1x)
# Crystal Reports - (1x)
# Cube-Daten - (1x)
# Cubes - (7x)
# Customer Transition - (2x)
# Cut Over Planning - (1x)
# DB Connect - (1x)
# DB Planung - (2x)
# DB2 - (4x)
# DB2 6.x - (1x)
# DB2 Data Warehouse - (1x)
# DB2 Data Warehouses - (1x)
# DB2 Datenbanken - (2x)
# DB2 Planung - (1x)
# DB2 Replikationstools - (1x)
# DFÜ Infrastruktur - (1x)
# DSAG-Prüfleitfaden - (1x)
# DSGVO - (4x)
# DSO Objekte - (4x)
# DWH - (2x)
# Dashboard - (2x)
# Dashboards - (5x)
# Data Mining - (1x)
# Data Science - (1x)
# Data Warehouse - (2x)
# Data Warehouse Design - (1x)
# Data Warehouse Personal - (1x)
# Data-Mining-Methoden - (1x)
# Data-Science-Plattformen - (1x)
# Data-warehouse - (1x)
# DataStage - (1x)
# Datei-basierten Schnittstelle - (1x)
# Daten-Extraktion - (1x)
# Datenanalyse - (2x)
# Datenaufbereitung - (1x)
# Datenaustausch - (1x)
# Datenbank - (1x)
# Datenbankdesign - (1x)
# Datenbanken - (4x)
# Datenbankprogrammierung - (1x)
# Datenbanksysteme - (1x)
# Datenbanksystemen - (1x)
# Datenbewirtschaftung - (1x)
# Datenbewirtschaftung und -modelle - (1x)
# Datenerfassung - (1x)
# Datenextraktion - (1x)
# Datenflussanpassungen - (1x)
# Dateninfrastruktur - (1x)
# Datenmigration - (2x)
# Datenmodelle - (3x)
# Datenmodellierung - (10x)
# Datenmodells - (1x)
# Datenschutz-Tools - (1x)
# Datenschutzanforderungen - (1x)
# Datenverwaltung - (1x)
# Datenvisualierung - (1x)
# Datenübernahme - (1x)
# Days Payables Outstanding - (1x)
# Days Sales Outstanding - (1x)
# Deckungsbeitragsrechnung - (2x)
# Deploy - (1x)
# Design Studio - (1x)
# Design-Phase - (1x)
# Designstudio - (1x)
# DevOps - (1x)
# Dialogentwicklung - (1x)
# Dialogprogrammierung - (1x)
# Dokumentenverwaltung - (1x)
# Dynpro - (1x)
# Dynpros - (1x)
# EAM - (3x)
# ECC 6.0 EHP 7 - (1x)
# ECC 6.0 EHP7 - (2x)
# EHP7 FOR SAP ERP 6.0 - (4x)
# EICON ISDN Router - (1x)
# ELM Schweiz - (1x)
# EM - (2x)
# EP - (1x)
# EP Portal - (1x)
# ERP - (5x)
# ERP 4.6.C - (1x)
# ERP 4.6.C bis EHP7 FOR SAP ERP 6.0 - (1x)
# ERP 4.6C - (3x)
# ETL - (4x)
# ETL Prozess - (1x)
# ETL-Strecken - (1x)
# ETL–Tool - (1x)
# EU-DSGVO - (3x)
# EU-Datenschutzgrundverordnung - (1x)
# EWM - (1x)
# Eclipse - (1x)
# Eclipse IDE - (1x)
# EhP3 - (1x)
# Einführungsprojekt - (2x)
# Einkaufsreporting - (1x)
# Enterprise Architect - (1x)
# Enterprise Mobility - (1x)
# Enterprise Portal - (3x)
# Entscheidungsbäumen - (1x)
# Entscheidungsvorlagen - (1x)
# Entwicklungs- und Anwendungstechnik - (1x)
# Entwicklungsbegleitung - (1x)
# Ereignisgesteuerte Prozessketten - (1x)
# Eventim - (2x)
# Excel - (9x)
# Explore - (2x)
# Exportdateien - (1x)
# Extraktoren - (2x)
# Extraktorerweiterungen - (2x)
# FCT - (1x)
# FI - (8x)
# FI-CA - (1x)
# FI/CO - (2x)
# FICO - (1x)
# Fachkonzept - (1x)
# Faktentabellen - (1x)
# Faktura - (1x)
# Fehleranalyse - (3x)
# Feinkonzept - (8x)
# Finanzapplikation - (1x)
# Finanzapplikationen - (1x)
# Finanzierungsszenarios - (1x)
# Finanzprozesse - (1x)
# Finanzreporting - (1x)
# Finanzsysteme - (3x)
# Finanzsystems - (2x)
# Fiori - (4x)
# First Level Support - (1x)
# Flatfile Uploads - (1x)
# Forecast- & Planungsplattform - (1x)
# Forecasts - (1x)
# Forms - (2x)
# Formulare - (1x)
# Framework Manager - (4x)
# Frameworks - (1x)
# Frontend - (3x)
# Frontend-Webseite - (1x)
# Funktionsbausteinen - (3x)
# GIT - (1x)
# GPM - (1x)
# Gemeinkostenberichte - (1x)
# Gemeinkostenreporting - (2x)
# Geschäftslogik - (1x)
# Geschäftspartnerkonsolidierung - (2x)
# Geschäftsprozessanalyse - (1x)
# Geschäftsprozessen - (1x)
# GitLab - (1x)
# Go Live - (3x)
# Go-Life - (4x)
# Go-Live - (1x)
# Go-Live Support - (1x)
# Go-Live-Support - (1x)
# Go-To-Market Strategie - (1x)
# Go-To-Market Strategien - (1x)
# GoLive - (1x)
# GoLive Support - (3x)
# GoLive Unterstützung - (2x)
# Going Live - (1x)
# Google Analytics - (1x)
# Google Or-Tools - (1x)
# Groupware - (1x)
# GuV - (5x)
# GuV Planung - (1x)
# GxP - (1x)
# HANA - (5x)
# HANA Calculation Views - (1x)
# HANA Cloud MS - (2x)
# HCI - (3x)
# HCM - (2x)
# HCM PA, PY, PT, Berechtigungen, VM, PE, Auswertungen, Prozessberatung - (1x)
# HERMES - (1x)
# HERMES 5 - (1x)
# HP-DataProtector - (1x)
# HP/Compaq Server - (1x)
# HR - (2x)
# HR-Bausteine Abrechnung, Administration - (1x)
# HR-Bausteines Organisationsmanagement - (1x)
# HTML - (7x)
# HTML5 - (1x)
# Harmonisierungsprojekt - (1x)
# Hintergrundsystems - (1x)
# Historisierungskonzept - (1x)
# Hypercarephase - (2x)
# IBM Analytics - (1x)
# IBM COGNOS TM1 - (1x)
# IBM Cognos - (3x)
# IBM Cognos 10 & 11 - (1x)
# IBM Cognos 10 - (5x)
# IBM Cognos 10 BI - (1x)
# IBM Cognos 10 BI Metadata Model - (1x)
# IBM Cognos 10 BI Multidimensional - (1x)
# IBM Cognos 8-11 - (1x)
# IBM Cognos 8/10 - (1x)
# IBM Cognos Analytics - (1x)
# IBM Cognos Analytics / BI - (1x)
# IBM Cognos BI - (3x)
# IBM Cognos BI 10 - (1x)
# IBM Cognos Business Intelligence - (1x)
# IBM Cognos Data Manager - (1x)
# IBM Cognos DataManager - (1x)
# IBM Cognos Framework Manager - (2x)
# IBM Cognos TM1 - (12x)
# IBM Cognos TM1. - (1x)
# IBM Cognos-Datamanager - (1x)
# IBM Cognos10 - (1x)
# IBM Cognos8 - (1x)
# IBM DB2 - (1x)
# IBM DB2 DWH - (1x)
# IBM DB2 Datenbank - (1x)
# IBM DB2-Tools - (1x)
# IBM DataWarehouse - (1x)
# IBM IS DataStage - (1x)
# IBM Netezza - (1x)
# IBM Netezza Appliance - (1x)
# IBM Planning Analytics - (3x)
# IBM PureData System for Analytics - (1x)
# IBM SPSS Modeler - (3x)
# IBM TM1 - (1x)
# IBM WebSphere - (1x)
# ICT Operative Sicherheitsbeauftragte SAP - (1x)
# IPMA - (1x)
# ISDN - (1x)
# ISEC7 Mobility4SAP - (1x)
# IT - (1x)
# IT Architektur - (1x)
# IT Infrastruktur - (1x)
# IT Landschaft - (1x)
# IT Projektmanagement - (1x)
# IT Service Management - (1x)
# IT-Architektur - (4x)
# IT-Infrastruktur - (1x)
# IT-Netzwerken - (1x)
# IT-Transformationen - (1x)
# ITIL - (2x)
# IVIP - (1x)
# Impact-Analyse - (1x)
# Implementierungsüberwachung - (2x)
# Inbound & Outbound Schnittstellen - (2x)
# Individualentwicklung - (1x)
# InfoObjekte - (2x)
# Infocubes - (1x)
# Information Retrieval - (1x)
# Informationsextraktion - (1x)
# Instore- - (1x)
# Integrationsszenarien - (1x)
# Integrierte Planung - (1x)
# Internet - (1x)
# Investitionsplanung - (2x)
# J2EE - (1x)
# JAVA - (2x)
# JBoss - (1x)
# JIRA - (2x)
# Java - (6x)
# Java EE - (1x)
# Java SE 8 - (1x)
# Java Stack - (1x)
# JavaScript - (1x)
# Javascript - (3x)
# Jira - (3x)
# Juniper - (1x)
# KI - (1x)
# KNIME - (2x)
# KPI Messungen - (1x)
# Kanban - (1x)
# Klassifizierungsverfahren - (1x)
# Knowledge Transfer - (1x)
# Kommentarlösung - (1x)
# Konditionsrechnung - (1x)
# Konditionsreporting - (1x)
# Kontierungsdaten - (1x)
# Kontrollsystem - (1x)
# Konzeptunterstützung - (1x)
# Konzeptvalidierung - (1x)
# Konzernplanung - (2x)
# Konzernsystemen - (1x)
# Korpuslinguistik - (1x)
# Kosten Controlling - (1x)
# Kosten-Planungslösung - (1x)
# Kostenartenrechnung - (1x)
# Kostenkalkulationen - (1x)
# Kostenplanung - (2x)
# Kostenrechnung - (1x)
# Kostenstellenberichte - (1x)
# Kostenstellenplanung - (2x)
# Kostenstellenverantwortung - (1x)
# Kunden-, Aktivitäts- und Opportunity Management - (1x)
# Kundenentwicklung - (1x)
# Kurzkontierungen - (1x)
# LCSSA-Form - (1x)
# LIMS - (1x)
# LIMS System - (1x)
# LIS Infostrukturen - (2x)
# LOGA - (1x)
# LOLA - (1x)
# Linear Programming - (1x)
# Linux - (2x)
# Logistik-Cockpit - (1x)
# Lohnkonten- und Stammdatenmigration - (4x)
# Lohnkonto - (1x)
# Longrange - (1x)
# Lumira - (4x)
# Lumira Designer - (1x)
# Löschkonzept - (1x)
# Lösungsansatz - (1x)
# MAM - (1x)
# MB VANS - (1x)
# MES - (1x)
# MIS ALEA - (1x)
# MIS ALEA 4.1 - (1x)
# MIS Alea - (1x)
# MM - (9x)
# MM_&RE_-Objekten - (1x)
# MODA - (1x)
# MQS-LI CAQ - (1x)
# MQT Tabellen - (1x)
# MS Access - (2x)
# MS Dos - (1x)
# MS Excel - (12x)
# MS Outlook - (1x)
# MS Power BI - (1x)
# MS Power Point - (3x)
# MS Project - (2x)
# MS SQL Server - (7x)
# MS SSIS - (1x)
# MS Skype for Business - (1x)
# MS Windows - (2x)
# MS Word - (11x)
# MS-Access - (5x)
# MS-Excel - (1x)
# MS-Office - (1x)
# MS-SQL - (2x)
# MS-SQL Server - (1x)
# MS-Windows - (1x)
# Machbarkeitsstudie - (5x)
# Machine Learning - (2x)
# Make To Order - (1x)
# Make To Stoke - (1x)
# Management Consultant - (1x)
# Management Dashboards - (1x)
# Management Summary - (1x)
# Managementtools - (1x)
# Marketing - (1x)
# Master Data Governance - (1x)
# Master- und Transactional Data - (1x)
# Matlab - (2x)
# Mediaassetmanagement Tools - (1x)
# Metadatenmodellierung - (1x)
# Microsoft Dynamics AX - (2x)
# Microsoft Office 365 - (1x)
# Microsoft Project - (1x)
# Microsoft SQL Server DWH - (1x)
# Microsoft SSIS - (1x)
# Microsoft Sharepoint - (1x)
# Microsoft Windows - (2x)
# Migration Templates - (1x)
# Migrationsprojekten - (1x)
# Minor Change Requests - (1x)
# Miro - (1x)
# Mobile App-Entwicklung - (1x)
# Mobile Lösungen - (2x)
# Mobile Solution - (1x)
# Multi Resource Scheduling - (1x)
# Multi-Backend-Anbindung - (2x)
# Multidimensionale Datenbanken - (2x)
# Multidimensionale Planungssysteme - (1x)
# Multiprovidern - (7x)
# MySQL - (3x)
# N4DS - (2x)
# N4DS Frankreich - (1x)
# NGBA - (2x)
# NKF - (4x)
# NORTEL - (1x)
# Nach-Go-Live-Phase - (1x)
# Natural - (1x)
# Negativzeitwirtschaft - (1x)
# Netzwerkarchitektur - (1x)
# Netzwerkinfrastruktur - (1x)
# Netzwerktechnik - (1x)
# Netzwerkumgebungen - (1x)
# Notfallbenutzermanagement - (1x)
# ODP DS - (1x)
# ODP Datenquellen - (1x)
# ODS Objekte - (3x)
# OLAP Cube Modellierung - (1x)
# OLAP Datenquellen - (1x)
# OLAP Provider - (1x)
# OM - (6x)
# ORACLE - (1x)
# OpenHub - (1x)
# Opportunity Prozesses - (1x)
# Opportunity- und Vertragsmanagement - (1x)
# Optimierungs-/Harmonisierungspotential - (1x)
# Optimierungspotential - (1x)
# Oracle - (8x)
# Oracle 10g - (1x)
# Order To Cash - (1x)
# Ordnungssysteme - (1x)
# Organisationsmanagement - (4x)
# Outbound - (1x)
# Outbound Schnittstellen - (1x)
# Overhead Management - (1x)
# PA - (13x)
# PAISY - (2x)
# PFCG - (1x)
# PFCG-Rollen - (1x)
# PHP - (3x)
# PI Planning - (1x)
# PL/SQL - (1x)
# PM - (4x)
# PMI - (1x)
# PP - (11x)
# PP-MES - (1x)
# PRINCE2 - (1x)
# PS - (1x)
# PSA - (3x)
# PSCD - (8x)
# PT - (10x)
# PY - (13x)
# PaPM - (1x)
# Paisy - (1x)
# Parallelabrechnung - (2x)
# Parameter Optimierung - (1x)
# Patch-Level Upgrades - (1x)
# Patch-level Upgrades - (1x)
# People Soft - (2x)
# Performance Optimierung - (1x)
# Performance-Analysen - (1x)
# Personalabrechnung - (2x)
# Personalabrechnung Österreich - (1x)
# Personalabrechnungsverfahrens - (1x)
# Personaladministration - (3x)
# Personalentwicklung - (1x)
# Personalführung - (2x)
# Personalreporting - (1x)
# Pilot - (1x)
# Pilot Projekt - (2x)
# Pilotprojekt - (1x)
# Plan/Ist-Vergleich - (1x)
# Plandaten - (1x)
# Plandatenupload - (1x)
# Planning Analytics - (1x)
# Planungs- & Forecastlösung - (1x)
# Planungs- und Data-Science-Software - (1x)
# Planungsanwendung - (2x)
# Planungsanwendungen - (1x)
# Planungsapplikationen - (1x)
# Planungsfunktionen - (2x)
# Planungslogiken - (1x)
# Planungsmappen - (1x)
# Planungsplattform - (1x)
# Planungsplattformen - (1x)
# Planungstool - (1x)
# Planungs–Systems - (1x)
# Portaladministration - (1x)
# Powerpoint - (1x)
# Predictive Analytics - (1x)
# Prepare - (2x)
# Prevero p7 - (1x)
# Prince 2 - (1x)
# Principal Consultant - (1x)
# Pro-gramm- und Projektmanagement - (1x)
# ProClarity - (1x)
# Product Ownership - (2x)
# Product Roadmaps - (1x)
# Produkt Management - (1x)
# Produktionsdaten - (1x)
# Produktionssystemen - (1x)
# Produktivexport - (1x)
# Produktivmigration - (2x)
# Produktkonfiguration - (1x)
# Professional Planner - (2x)
# Programmleitung - (2x)
# Projekt- & Changemanagement - (6x)
# Projekt- und Zeitplans - (1x)
# Projektassistenz - (1x)
# Projektberichte - (1x)
# Projektcontrolling Systemen - (1x)
# Projektführung - (1x)
# Projektkalkulation - (1x)
# Projektkalkulationen - (1x)
# Projektkoordination - (1x)
# Projektleitung - (12x)
# Projektleitungsaufgaben - (1x)
# Projektmanagement - (17x)
# Projektplanerstellung - (1x)
# Projektplanung - (4x)
# Projektplanung und -management - (1x)
# Projektplanung und -steuerung - (1x)
# Projektplanung, -leitung und -steuerung - (1x)
# Projektreporting - (1x)
# Projektstrukturierung - (1x)
# Projektüberwachung und -steuerung - (1x)
# Proof of Concept - (2x)
# Prototyping - (1x)
# Prototyps - (1x)
# Prozess Access Control - (2x)
# Prozess- /und Migrations Validierung - (1x)
# Prozess-detaillierung - (1x)
# Prozessanalyse - (3x)
# Prozessberatung - (9x)
# Prozessdefinitionen - (1x)
# Prozessdesign - (3x)
# Prozessdokumentationen - (1x)
# Prozessergänzung - (1x)
# Prozessharmonisierung - (2x)
# Prozessketten - (1x)
# Prozessvalidierung - (1x)
# Prüfdatenerfassung - (1x)
# Prüfdatenmigration - (1x)
# Prüfmittelanbindung - (1x)
# Prüfmittelverwaltung - (1x)
# Prüfzeugniserstellung - (2x)
# Pseudonymisierung - (1x)
# Public Sector Collection and Disbursement - (1x)
# Purchase To Pay - (1x)
# Python - (10x)
# Python Data Science Stack - (1x)
# QM - (35x)
# QM Business Prozesse - (1x)
# QM&EAM - (1x)
# QM- - (1x)
# QM-/Meldungs-Reporting - (1x)
# QM-IDI - (1x)
# Qualität sicherstellen - (1x)
# Qualitätsmanagement - (1x)
# Qualitätssicherung - (3x)
# Quellsystemanalyse - (1x)
# Queries - (5x)
# Query Analyzer - (1x)
# Query Designer - (3x)
# Queryentwicklung - (1x)
# R - (2x)
# R/3 - (1x)
# REST API - (1x)
# RFC Funktionsbausteine - (1x)
# RFC/RFCACL-Rechte - (1x)
# RTI - (3x)
# RUP UX-Design - (1x)
# RapidMiner - (2x)
# Realisierungsaufträgen - (3x)
# Realize - (1x)
# Rechnungserfassung - (3x)
# Rechte - (2x)
# Regeln - (8x)
# Reklamationsmanagement - (1x)
# Relationale Datenbanken - (4x)
# Relationales- und multidimensionales Datawarehouse - (1x)
# Replikationstools - (1x)
# Report - (1x)
# Report Studio - (1x)
# Reporting - (18x)
# Reports - (10x)
# Requirements Engineering - (3x)
# Reservationsprozesse - (2x)
# Ressourcen- und Budget Planung - (1x)
# Ressourcenplanung - (2x)
# Retail - (1x)
# Risiko & Change Management - (1x)
# Risiko- und Change Management - (1x)
# Roll Out Management - (1x)
# Rollen - (16x)
# Rollen-basiertes User Management - (1x)
# Rollenbau - (2x)
# Ruby on Rails - (1x)
# Run - (1x)
# S/4 Daten - (1x)
# S/4 HANA - (3x)
# S/4 HANA Cloud - (1x)
# S/4 Release 1809 - (1x)
# S/4 Template - (1x)
# S/4 Änderungen - (1x)
# S/4: Business-Use - (1x)
# S/4HANA - (2x)
# S/4HANA Cloud 1905. - (1x)
# S/HANA Cloud und OnPremise - (1x)
# S4/HANA - (2x)
# S4/HANA Baseline 1909 - (1x)
# S4/HANA Cloud - (1x)
# S4/HANA Release 1809 - (1x)
# S4/Hana Datenbank - (1x)
# SAFe - (4x)
# SAP
# Projektmanagement - (1x)
# SAP (Advanced) Analysis for Office - (1x)
# SAP - (8x)
# SAP 4.7 - (4x)
# SAP Abrechnung PY - (1x)
# SAP Activate - (1x)
# SAP Add On MRSS - (1x)
# SAP Analysis For Office - (1x)
# SAP Analysis for Office - (3x)
# SAP Analytics - (2x)
# SAP Archivierung - (3x)
# SAP BEx - (1x)
# SAP BEx Queries - (1x)
# SAP BI - (3x)
# SAP BI 4.0 - (1x)
# SAP BI 4.0 Enterprise Platform - (1x)
# SAP BI 4.0 Enterprise Plattform - (2x)
# SAP BI 4.1 - (1x)
# SAP BI BW on HANA Systems - (1x)
# SAP BI Berechtigungen - (1x)
# SAP BI Integrierte Planung - (1x)
# SAP BI-IP - (2x)
# SAP BO Xcelsius - (1x)
# SAP BPC - (1x)
# SAP BW - (45x)
# SAP BW 3.0 - (1x)
# SAP BW 7.0 & 7.3 - (1x)
# SAP BW 7.0 - (9x)
# SAP BW 7.3 - (2x)
# SAP BW 7.4 - (3x)
# SAP BW 7.4 on HANA - (3x)
# SAP BW 7.5 on HANA - (1x)
# SAP BW Datawarehouse - (1x)
# SAP BW IP - (1x)
# SAP BW on HANA - (2x)
# SAP BW, EP, BO - (1x)
# SAP BW-IP - (4x)
# SAP Basis - (1x)
# SAP Benutzeradministration - (1x)
# SAP Berechtigungen - (4x)
# SAP Berechtigungskonzept - (1x)
# SAP Berechtigungskonzepte - (1x)
# SAP Berechtigungskonzepten - (1x)
# SAP Bex Query Designer - (1x)
# SAP Business  Suite on HANA - (1x)
# SAP Business Information Warehouse - (1x)
# SAP Business Objects - (1x)
# SAP Business Objects Analysis - (1x)
# SAP Business Warehouse - (1x)
# SAP Business Warehouses - (1x)
# SAP C4C - (1x)
# SAP CRM - (7x)
# SAP CRM 7.0 - (5x)
# SAP CRM Berechtigungen - (1x)
# SAP CRM Sales - (1x)
# SAP CRM Service - (1x)
# SAP CRM WebUI - (2x)
# SAP CRM on Premise - (1x)
# SAP CRM on premise - (1x)
# SAP Chargenrückverfolgung - (1x)
# SAP Cloud - (1x)
# SAP Cloud Applications Studio - (1x)
# SAP Cloud Platform - (4x)
# SAP Cloud Platform Integration - (6x)
# SAP Cloud for Customer - (4x)
# SAP Competence Center - (1x)
# SAP Compliance - (3x)
# SAP Compliance Tools - (2x)
# SAP Daten - (1x)
# SAP Desktop Connection - (1x)
# SAP ECC / SEM-BCS - (1x)
# SAP ECC 6 CO, FI, PS, MM, SD - (1x)
# SAP ECC 6.0 - (6x)
# SAP ECC 6.0 CO, FI, MM - (1x)
# SAP ECC 6.0 EHP 4 CO, FI, PS - (1x)
# SAP ECC 6.0 FI, PS, CO, MM - (1x)
# SAP ECC 6.0 SD, CO - (1x)
# SAP ECC 6.0 SD, CO, FI, MM - (1x)
# SAP ECC Berechtigungen - (1x)
# SAP ECC und HCM - (1x)
# SAP ECC und HCM System - (1x)
# SAP ECC und HCM Systemen - (1x)
# SAP ERP - (23x)
# SAP ERP 4.6 - (1x)
# SAP ERP 6.0 - (3x)
# SAP ERP CC Systems - (1x)
# SAP ERP Logistik - (1x)
# SAP ERP MM/PS - (1x)
# SAP ERP SD/FI/CO - (1x)
# SAP ERP inkl. HR - (2x)
# SAP ERP/CRM - (1x)
# SAP Enterprise Portal - (1x)
# SAP FI - (1x)
# SAP GRC - (2x)
# SAP GRC AC - (1x)
# SAP GRC AC 5.3 - (1x)
# SAP GRC Access Control 5.3 - (1x)
# SAP HANA - (1x)
# SAP HCI - (6x)
# SAP HCM - (23x)
# SAP HCM Berechtigungen - (1x)
# SAP HCM PA & PY - (2x)
# SAP HCM System - (1x)
# SAP HCM Systeme - (1x)
# SAP HCM Systems - (1x)
# SAP HR Bereichen PA, PY, OM, PT, SapScript, HR Forms, Reporting - (3x)
# SAP HR PA & PY - (1x)
# SAP HR-OM - (1x)
# SAP HR310 - (1x)
# SAP Hybris C4C - (10x)
# SAP Hybris Cloud for Customer - (13x)
# SAP Hybris Cloud for Sales - (1x)
# SAP Hybris Sales Cloud - (9x)
# SAP Hybris Sales Cloud-Systems - (1x)
# SAP ILM - (8x)
# SAP IS-U - (1x)
# SAP Identity & Access Management - (1x)
# SAP Klassenverwaltung - (4x)
# SAP LAW - (1x)
# SAP Logistik - (1x)
# SAP MRS - (1x)
# SAP Meldungswesen - (2x)
# SAP Module PA/PY - (1x)
# SAP Modulen BC, FI, CO, SD, MM, LE, PP, QM, PM, CRM, IS-U - (1x)
# SAP Multichannel Foundation for Utilities - (4x)
# SAP Net Weaver 7.4 - (1x)
# SAP NetWeaver 7.0 - (1x)
# SAP NetWeaver BW - (1x)
# SAP NetWeaver Business Client - (2x)
# SAP PAPM - (2x)
# SAP PM MRSS - (1x)
# SAP PP - (2x)
# SAP Personalabrechnung Österreich - (1x)
# SAP Personalwirtschaft - (1x)
# SAP Personalwirtschaft/Stammdaten - (1x)
# SAP Profitability and Performance Management - (2x)
# SAP Prozess Workflow - (5x)
# SAP Prüfmittelverwaltung - (1x)
# SAP QM - (4x)
# SAP QM / EAM - (1x)
# SAP QM/PM - (1x)
# SAP Query - (1x)
# SAP Query Designer - (1x)
# SAP R/3 - (2x)
# SAP R/3 HCM - (1x)
# SAP R/3 HCM Ministamm - (1x)
# SAP R/3 HCM PY - (1x)
# SAP R/3 HR - (3x)
# SAP R/3 HR Administration, OM, Abrechnung, Zeitwirtschaft, Schnittstellen, Berechtigungen - (1x)
# SAP R/3 HR Bausteines Organisationsmanagement - (1x)
# SAP R/3 HR COLORADO - (3x)
# SAP R/3 HR Colorado - (3x)
# SAP R/3 HR Organisationsmanagement - (1x)
# SAP R/3 HR Systems - (1x)
# SAP R/3 HR-Bausteine Abrechnung, Administration, Zeitwirtschaft und Organisationsmanagement - (1x)
# SAP R/3 Zeitwirtschaft - (1x)
# SAP Rollenpflege - (1x)
# SAP SEM-BCS 4.0 - (1x)
# SAP Schnittstellen QM-IDI, LI-MQS; AIF, IDOC - (1x)
# SAP Security Audit Logs - (1x)
# SAP Smart Form - (5x)
# SAP Software - (1x)
# SAP Solution Consultant Logistics - (1x)
# SAP Solution Manager - (3x)
# SAP Solution Manager 702 – SP17 - (1x)
# SAP Solution Manager Berechtigungen - (1x)
# SAP Solution Manager Ticketsystem - (3x)
# SAP Stammdatenerstellung- und Pflege - (1x)
# SAP Standard - (1x)
# SAP Standardtools zur User- und Rollenpflege - (1x)
# SAP System - (2x)
# SAP Systeme - (1x)
# SAP Systemen - (1x)
# SAP Systemvermessung - (1x)
# SAP Test Automation Tool - (1x)
# SAP Test Automization Tool - (1x)
# SAP Tools - (1x)
# SAP Transak - (1x)
# SAP Transaktionen SUIM / SM19 / SM20 / - (1x)
# SAP Transportwesens - (1x)
# SAP User - (1x)
# SAP User- und Rollenadministration - (1x)
# SAP Useradministration - (2x)
# SAP Warenwirtschaft - (1x)
# SAP Web Client UI - (1x)
# SAP Work Manager - (1x)
# SAP XI - (1x)
# SAP ZBV - (1x)
# SAP Zeitwirtschaft - (1x)
# SAP basierten BI Plattform - (1x)
# SAP for Utilities - (2x)
# SAP- Berechtigungs-konzepten - (1x)
# SAP-Benutzerklassifizierung - (1x)
# SAP-Daten - (1x)
# SAP-Datenarchivierung und -anonymisierung - (1x)
# SAP-MES-SAP - (3x)
# SAP-Rollen - (1x)
# SAP-Systeme - (1x)
# SAP-Systemen - (3x)
# SAP-Tabellen - (2x)
# SAP-Umfeld - (2x)
# SAP-Users - (1x)
# SAP-Zugriffe - (1x)
# SAPUI5 - (2x)
# SAPscript - (1x)
# SBOP Analysis for Office - (2x)
# SCRUM - (3x)
# SD - (10x)
# SD Support - (1x)
# SEM-BCS - (2x)
# SMART ERP - (1x)
# SOX - (2x)
# SQL - (6x)
# SQL Server - (3x)
# SQL Server 2005 - (1x)
# SQL Server Integration Services - (1x)
# SSCUI - (2x)
# SSIS - (1x)
# ST01 - (1x)
# SU01d - (1x)
# SUIM - (1x)
# Sales - (1x)
# Sales Prozesse - (1x)
# Sales-Reporting - (1x)
# Schemen - (8x)
# Schnittstelle - (5x)
# Schnittstellen - (13x)
# Schnittstellenanbindung - (1x)
# Schnittstellenbeschreibungen - (1x)
# Schnittstellendefinition - (3x)
# Schnittstellenentwicklung - (1x)
# Schnittstellenteams - (2x)
# Schnittstellenverarbeitung - (1x)
# Schnittstellenverwaltung - (1x)
# Scrum - (6x)
# Second und Third-Level-Support - (4x)
# Security - (1x)
# Sem-BCS Konten - (1x)
# Semi-Agilen - (1x)
# Server Technologien - (1x)
# Service Level Agreement - (2x)
# Servicemanagement - (3x)
# Sharepoint - (1x)
# Skype - (1x)
# SmartForms - (2x)
# Software-Evaluation - (1x)
# Software-Updates - (1x)
# Softwarearchitekturen - (1x)
# Softwareauswahl - (3x)
# Softwaretests - (1x)
# Softwareupdates - (1x)
# Solution Manager Prozess Modell - (1x)
# Solution Specification - (2x)
# Sophos - (1x)
# Sperr- und Löschkonzepte - (1x)
# Sperrkonzept - (1x)
# Splunk - (1x)
# Stabilisierungsmaßnahmen - (2x)
# Stabilitätsstudien - (1x)
# Staging Area - (8x)
# Staging- und ETL Modells - (1x)
# Stakeholdermanagement - (1x)
# Stamm- und Bewegungsdaten - (4x)
# Stamm- und Lohnkontodaten - (6x)
# Stammdaten - (9x)
# Stammdatenanpassung - (1x)
# Stammdatenpflege - (1x)
# Stammdatenübernahme - (1x)
# Starschema - (1x)
# Strategieberatung - (1x)
# Strategische Unternehmensführung - (1x)
# Struktur- und Ressourcenplanung - (2x)
# Subsystemen - (1x)
# Supportuser-Konzept - (1x)
# Switchings - (1x)
# Sybase Unwired Platform 1.5.5 - (1x)
# System Vermessung - (1x)
# Systemadministration - (5x)
# Systemanalyse - (2x)
# Systembeschreibung - (1x)
# Systembetreuung - (1x)
# Systemintegration - (1x)
# Systemvermessung - (1x)
# TM - (2x)
# TM1 - (8x)
# Tableau - (2x)
# Taisy - (1x)
# Taksy - (1x)
# Teamleiter - (1x)
# Technische Konzepterstellung - (1x)
# Technische Projektleitung - (1x)
# Teilprojektleitung - (3x)
# Teilprojektplanung und -steuerung - (1x)
# Template - (2x)
# TensorFlow - (2x)
# Test Driven Development - (1x)
# Test Management Work Center - (1x)
# Test- & Qualitätssicherung - (2x)
# Test- und Go-Life Koordination - (1x)
# Test- und Projektmanagement - (1x)
# Testkonzept - (1x)
# Testkonzepterstellung - (3x)
# Testkonzeption - (1x)
# Testmanagement - (1x)
# Testsystem - (2x)
# Testsystemen - (1x)
# Testumgebung - (1x)
# Testunterstützung - (2x)
# Text Mining - (1x)
# Ticketaufbereitung - (1x)
# Tomcat - (1x)
# Transaktionen - (1x)
# Transaktionslisten - (1x)
# Transferpreisermittlung - (1x)
# Transformationsroutinen - (1x)
# Transformer - (1x)
# Transformer Cubes - (1x)
# Transitionmangement - (1x)
# Transportüberwachung - (1x)
# Trendanalyse - (1x)
# UAT - (1x)
# UME - (1x)
# UX/UI-Design - (2x)
# Umsatz- und Konditionsplanung - (1x)
# Umstellungsstrategie - (1x)
# Uniserv - (1x)
# Usability-Testing - (2x)
# User Acceptance Test - (1x)
# User Management Engine - (1x)
# User Self Service - (1x)
# Useradministration - (1x)
# Useradministratoren - (1x)
# Useranlage - (1x)
# Usergruppen - (1x)
# Userstories - (1x)
# Userumstellungen - (1x)
# Userverwaltung - (1x)
# VBA - (5x)
# VBA Makro - (1x)
# VBA Makros - (1x)
# VEEAM - (2x)
# Veranstaltungsmanagement - (1x)
# Verantwortlichkeiten - (1x)
# Vertriebs- und Marketingszenarios - (1x)
# Vertriebsplanung - (1x)
# Vertriebsprozesse - (1x)
# Virtuelles Reporting - (2x)
# Visual Basic - (1x)
# Visual Studio - (1x)
# Vorhersagemodellen - (1x)
# WAD - (2x)
# Wasserfall - (1x)
# Web Services - (1x)
# Web-/ Application-Server - (1x)
# Web-Dynpro - (1x)
# Web-Entwicklung - (1x)
# WebApplicationDesigner - (1x)
# WebIntelligence - (2x)
# WebServices - (1x)
# Webapplikation - (3x)
# Webschnittstelle - (1x)
# Wegberechnung - (1x)
# Weka - (2x)
# Whitelisted DS - (2x)
# Windows - (2x)
# Windows Filesystem - (1x)
# Windows NT / 2000 / 2003 / XP - (1x)
# Windows NT/2000/XP - (1x)
# Windows Server Infrastruktur - (1x)
# Wissenskonsolidierung - (1x)
# Wissenstransfer - (1x)
# Workflow - (1x)
# Workmanager - (2x)
# XAMS - (3x)
# XAMS-Tracedaten - (1x)
# XML - (2x)
# Xcelsius - (2x)
# Xcelsius Dashboard - (1x)
# Xcelsius Dashboards - (1x)
# Xiting Authorizations Management Suite - (2x)
# Xiting Role replicator - (1x)
# Xiting Times - (1x)
# Xiting Times Customizing - (1x)
# Xiting XAMS - (2x)
# ZBV - (1x)
# Zahlungsverkehr - (1x)
# Zeitauswertung - (1x)
# Zeitplanung - (1x)
# Zeitreihen - (1x)
# Zeitreihenanalysen - (1x)
# Zeitreihenanalysesoftware - (1x)
# Zeitwirtschaft - (3x)
# Zentrale Authentifizierung - (1x)
# Zentrale Benutzerverwaltung - (2x)
# Zugriffsschutz - (1x)
# after Go-Life - (2x)
# agiles, verteiltes Team - (1x)
# analytischen Datenbanken - (1x)
# betriebliche Altersversorgung - (1x)
# datei-basierten Schnittstelle - (1x)
# datenbankbasierte  Internet-Projekte - (1x)
# embedded BW - (1x)
# freie Strukturen - (1x)
# generische Extraktoren - (3x)
# genetic algorithm - (1x)
# iFlows - (1x)
# iOS - (1x)
# iViews - (3x)
# komplexe Datenflüsse - (1x)
# mobilen Geschäftsprozessen - (1x)
# multidimensionalen Datenquellen - (1x)
# multidimensionalen Reporting und Analyse - (1x)
# multidimensionalen und relationalen Analyse- und Berichtsstrukturen - (1x)
# natural Language Processing - (1x)
# on-Line Datenerfassung - (1x)
# oracle - (1x)
# pTs - (1x)
# prädiktiver Vorhersagemodelle - (1x)
# relationale und multidimensionale Datenquellen - (1x)
# relationalen Berichten - (1x)
# relationalen DWH - (1x)
# relationaler und multidimensionaler Reporting-Systeme - (1x)
# skalierte Agilität - (1x)
# techn. Anforderungskonzeptes - (1x)
# verteilten Teams - (2x)
# virtuellem  Reporting - (1x)
# webMethods - (1x)
# Übersicht - (1x)
# österreichische Personalabrechnung - (1x)
#
#  ---------------------------------------------------------------------
#
# => Tätigkeiten:
# Abbildung - (3x)
# Ableiten - (2x)
# Ableitung - (3x)
# Ablösung - (4x)
# Abstimmung - (2x)
# Ad-Hoc-Analysen - (1x)
# Adaption - (1x)
# Administration - (6x)
# Agile Testing - (2x)
# Aktivierung - (2x)
# Aktualisieren - (1x)
# Analyse - (26x)
# Analysen - (1x)
# Anbindung - (11x)
# Anlage - (1x)
# Anlegen - (1x)
# Anonymisieren - (1x)
# Anonymisierung - (1x)
# Anpassen - (1x)
# Anpassung - (8x)
# Anpassungen - (2x)
# Anschluss - (1x)
# Anwenderschulung - (4x)
# Anwenderschulungen - (2x)
# Anwendungsbetrieb - (1x)
# Anzeige - (3x)
# Archivieren - (5x)
# Archivierung - (3x)
# Aufbau - (32x)
# Aufnahme - (1x)
# Aufsetzen - (2x)
# Ausbau - (1x)
# Ausbildung - (1x)
# Auslagerung - (2x)
# Ausprägen - (1x)
# Ausprägung - (4x)
# Ausrollen - (1x)
# Auswerten - (1x)
# Auswertung - (5x)
# Auswertungen - (3x)
# Automatisierung - (2x)
# Bau - (6x)
# Beantragen - (1x)
# Bearbeiten - (4x)
# Bearbeitung - (4x)
# Begleitung - (1x)
# Benutzerschulung - (1x)
# Beraten - (4x)
# Beratung - (17x)
# Beschaffung - (2x)
# Betreuung - (9x)
# Betrieb - (8x)
# Bewertung - (4x)
# Coaching - (5x)
# Configuration - (1x)
# Congiguration - (1x)
# Consulting - (2x)
# Custom-Entwicklung - (1x)
# Customizing - (28x)
# Dashboarding - (1x)
# Definition - (35x)
# Design - (13x)
# Dokumentation - (8x)
# Dokumentieren - (1x)
# Durchführen - (8x)
# Durchführung - (15x)
# Durchführung Schulungen - (1x)
# Einarbeitung - (3x)
# Einbindung - (1x)
# Einführen - (2x)
# Einführung - (70x)
# Einführungen - (1x)
# Einhaltung - (1x)
# Einrichten - (4x)
# Einrichtung - (3x)
# Einstellung - (1x)
# Enhancements - (1x)
# Entwicklung - (27x)
# Entwicklungen - (2x)
# Erarbeiten - (2x)
# Erarbeitung - (3x)
# Ermittlung - (2x)
# Erneuerung - (1x)
# Erstellen - (14x)
# Erstellung - (43x)
# Eruieren - (1x)
# Erweiterung - (18x)
# Erweiterungen - (7x)
# Erzeugung - (2x)
# Export - (2x)
# Extraktion - (2x)
# Fachkonzeption - (1x)
# Fachliche Beratung - (1x)
# Fachliche Konzipierung - (1x)
# Fachliche Koordination - (1x)
# Fachliche Unterstützung - (3x)
# Fachliche und technisch Konzeptionierung - (1x)
# Fachliche und technische Konzeptionierung - (1x)
# Fachliche und technische Konzipierung - (2x)
# Fachliche und technische Unterstützung - (1x)
# Fachliche und technische Verantwortung - (1x)
# Feedback - (1x)
# Feedbackgespräche - (1x)
# Fehlerbehebung - (1x)
# Filtern - (2x)
# Finalisierung - (1x)
# Fine-Tuning - (9x)
# Finetuning - (1x)
# Functional Testing - (1x)
# Generierung - (1x)
# Gewichtung - (1x)
# Handover - (1x)
# Harmonisierung - (4x)
# Hinzufügen - (1x)
# IT Strategie - (1x)
# Implementation - (2x)
# Implementierung - (60x)
# Import - (2x)
# Installation - (3x)
# Installationen - (1x)
# Instandhaltung - (1x)
# Integration - (26x)
# Klären - (1x)
# Kommissionierung - (1x)
# Konfiguration - (1x)
# Konsolidierung - (5x)
# Konstruktion - (1x)
# Kontaktieren - (1x)
# Kontinuierliche Integration - (2x)
# Kontrollen - (1x)
# Konzept - (11x)
# Konzepte - (1x)
# Konzepten - (1x)
# Konzeption - (51x)
# Konzeptionelle Entwicklung - (1x)
# Konzeptionierung - (5x)
# Konzipieren - (1x)
# Koordination - (13x)
# Koordinierung - (1x)
# Kopieren - (1x)
# Korrektur - (3x)
# Korrekturen - (3x)
# Layout - (1x)
# Leitung - (16x)
# Löschen - (3x)
# Mapping - (1x)
# Marktrecherche - (2x)
# Migration - (16x)
# Migrationen - (2x)
# Mitwirkung - (1x)
# Mobile Instandhaltung - (2x)
# Modellierung - (4x)
# Moderation - (1x)
# Monitoring - (1x)
# Multidimensionale Analyse - (1x)
# Nacharbeiten - (1x)
# Nachbildung - (1x)
# Neuaufbau - (1x)
# Neukonzeptionierung - (1x)
# Nutzen - (1x)
# Nutzung - (5x)
# Objektorientierte Implementierungen - (1x)
# Optimierung - (7x)
# Optimierungen - (1x)
# Organisation - (4x)
# Organisieren - (1x)
# Pflege - (7x)
# Planung - (14x)
# Praktische Umsetzung - (5x)
# Produktion - (1x)
# Programmierkenntnisse - (1x)
# Programmierung - (4x)
# Prädiktiven Analyse - (1x)
# Präsentation - (1x)
# Prüfen - (1x)
# Prüfung - (2x)
# Realisieren - (1x)
# Realisierung - (20x)
# Recherche - (1x)
# Redesign - (3x)
# Release Wechsel - (2x)
# Releaseupgrades - (2x)
# Releasewechsel - (2x)
# Reorganisation - (1x)
# Replikation - (1x)
# Roll Outs - (1x)
# Roll-In - (1x)
# Roll-Out - (9x)
# Roll-outs - (1x)
# Rollout - (1x)
# Rollouts - (4x)
# Rückläufe tracken - (1x)
# SAP Beratung - (3x)
# SAP Customizing - (1x)
# SAP Steuerung - (1x)
# Schulen - (1x)
# Schulung - (21x)
# Schulungsdurchführung - (2x)
# Selektion - (1x)
# Sicherstellung - (1x)
# Sichtung - (1x)
# Simulation - (4x)
# Skalierung - (1x)
# Softwareentwicklung - (5x)
# Speichern - (1x)
# Sperren - (1x)
# Sperrens - (1x)
# Stabilisierung - (2x)
# Statische Auswertung - (1x)
# Statistische Auswertungen - (2x)
# Steuerung - (5x)
# Strategie - (1x)
# Strategien - (1x)
# Strukturierte Entwicklung - (1x)
# Strukturierung - (6x)
# Support - (20x)
# Supportaufgaben - (2x)
# Szenario-Analyse - (1x)
# Teamleitung - (2x)
# Technische Dokumentation - (1x)
# Technische Realisierung - (2x)
# Technische Umsetzung - (1x)
# Technisches Feinkonzept - (1x)
# Test - (8x)
# Testaktivitäten - (1x)
# Testen - (2x)
# Testexport - (1x)
# Testing - (8x)
# Testkonstrukte - (1x)
# Testlauf - (1x)
# Testläufe - (1x)
# Testmigration - (2x)
# Tests - (2x)
# Training - (2x)
# Transition - (1x)
# Transport - (1x)
# Trennung - (2x)
# Troubleshooting - (1x)
# Umbuchen - (1x)
# Umgang - (3x)
# Umorganisationen - (1x)
# Umsetzen - (1x)
# Umsetzung - (33x)
# Umstellen - (2x)
# Umstellung - (2x)
# Unterstützen - (2x)
# Unterstützung - (21x)
# Untersuchung - (1x)
# Validierung - (3x)
# Verarbeitung - (1x)
# Vereinfachung - (1x)
# Vereinheitlichung - (2x)
# Vergleich - (1x)
# Verknüpfung - (1x)
# Vermittlung - (3x)
# Versand - (1x)
# Versionierung - (1x)
# Verteilung - (2x)
# Vertrieb - (2x)
# Verwaltung - (4x)
# Verwendung - (2x)
# Veröffentlichung - (1x)
# Vorbereiten - (2x)
# Vorbereitung - (4x)
# Vorschlag - (1x)
# Vorstellen - (1x)
# Vorstellung - (2x)
# Wartung - (10x)
# Weiterentwicklung - (13x)
# Zusammenführen - (1x)
# Zusammenführung - (1x)
# Zusammentragen - (1x)
# abbilden - (1x)
# ad-hoc Analysen - (1x)
# administrieren - (1x)
# anpassen - (1x)
# aufbauen - (3x)
# bauen - (2x)
# beantragen - (2x)
# begleiten - (2x)
# definieren - (1x)
# definiert - (1x)
# dokumentieren - (1x)
# durchführen - (5x)
# durchgeführt - (3x)
# einführen - (1x)
# einstellen - (1x)
# entwickeln - (1x)
# erarbeiten - (3x)
# erarbeitet - (1x)
# ermittelt - (1x)
# ersetzen - (1x)
# erstelle - (1x)
# erstellen - (14x)
# erstellt - (1x)
# eruieren - (1x)
# erweitern - (1x)
# fachliche Klärung - (1x)
# fachliche Koordination - (1x)
# fachlicher Abstimmung - (1x)
# festlegen - (1x)
# functional Testing - (1x)
# getrennt - (2x)
# implementiere - (1x)
# implementiert - (1x)
# infomieren - (1x)
# konzeptionelle Ausarbeitung - (9x)
# konzeptionellen Ausarbeitung - (1x)
# koordiniert - (1x)
# neu erstellen - (1x)
# optimiert - (1x)
# organisieren - (1x)
# pflegen - (1x)
# prädiktiven Optimierung - (1x)
# präsentieren - (1x)
# reduzieren - (1x)
# schulen - (2x)
# sichergestellt - (1x)
# technische Abwicklung - (1x)
# technische Dokumentation - (1x)
# technische Durchführung - (1x)
# technische Realisierung - (6x)
# technische Umsetzung - (4x)
# technische und fachliche Beratung - (2x)
# technische und fachliche Einführung - (3x)
# technischen Konzipierung - (1x)
# technischen Machbarkeit - (1x)
# technisches Feinkonzept - (1x)
# tracken - (1x)
# umbauen - (1x)
# umsetzen - (1x)
# unterstütze - (2x)
# unterstützen - (1x)
# vergeben - (1x)
# vorbereiten - (1x)
# zusammenstellen - (1x)
# Ändern - (1x)
# Änderung - (4x)
# Überarbeiten - (3x)
# Überarbeitung - (1x)
# Überleitung - (1x)
# Überprüfen - (3x)
# Überprüfung - (2x)
# Übertragung - (1x)
# überarbeiten - (1x)
# überwachen - (5x)
#
#  ---------------------------------------------------------------------
#
# => Rollen:
# 1st Level support - (1x)
# ABAP-Entwickler - (1x)
# Advisor - (1x)
# Agile Tester - (4x)
# Ansprechpartnerin - (1x)
# Ansprechperson - (1x)
# Architekt - (1x)
# BI - (1x)
# Berater - (2x)
# Beraterin - (6x)
# Builder - (1x)
# Business Analyst - (2x)
# Business Consultant - (1x)
# Business Intelligence Developer - (1x)
# Client-Server Entwickler - (1x)
# Coach - (1x)
# Consultant - (15x)
# Data Scientist - (1x)
# Developer - (1x)
# Elektrotechnik - (1x)
# Entwickler - (15x)
# Fachliche Systembetreuung - (1x)
# Fachlicher Support - (3x)
# Gesamt Projektleiter - (1x)
# Gesamt-Projektleitung - (1x)
# Gesamtprojektleiter - (1x)
# Gruppenleiterin - (1x)
# Hauptumsetzerin - (1x)
# ICT Operative Sicherheitsbeauftragte SAP - (4x)
# IT-Schulungskoordinator - (1x)
# IT-Trainer - (1x)
# In-House Consultant - (1x)
# Integrationsspezialist - (1x)
# Kursleiter - (1x)
# Lead - (1x)
# Lead Transporte - (1x)
# Leader - (1x)
# Leading Consultant - (2x)
# Lösungsarchitekt - (4x)
# Manager - (1x)
# Managing Consultant - (2x)
# Mitarbeiterin - (1x)
# Mitarbeiterin Logistikzentrale - (1x)
# Mitglied des Projektteams - (3x)
# Modulberater - (1x)
# Netzwerkadministrator - (1x)
# Process Expert - (1x)
# Product Management - (1x)
# Product Owner - (3x)
# Product Owner Proxy - (3x)
# Programmer - (1x)
# Project Leader - (2x)
# Project Member - (6x)
# Projekt Manager - (3x)
# Projektkoordinator - (1x)
# Projektleiter - (21x)
# Projektleiterin - (3x)
# Projektleitung - (12x)
# Projektmanagement - (1x)
# Projektmitarbeiter - (37x)
# Projektmitarbeiterin - (4x)
# Projektmitglied - (6x)
# Referentin - (1x)
# Repräsentant - (1x)
# Requirements Engineer - (2x)
# SAP BW - (1x)
# SAP Berater - (1x)
# SAP Senior Consultant - (1x)
# SAP-Berater - (2x)
# SAP-Rollout Teammitglied - (1x)
# Sachbearbeitung - (1x)
# Senior / Managing Consultant - (1x)
# Senior Beraterin - (1x)
# Senior Consultant - (16x)
# Senior Managing Consultant - (5x)
# Senior Software Engineer - (1x)
# Service Executive - (2x)
# Service Management - (2x)
# Service Managers - (1x)
# Software Engineer - (10x)
# Softwareentwickler - (1x)
# Spezialistin für Designanforderungen - (1x)
# Stellvertreterin - (1x)
# Stellvertreterin für Berechtigungsadministratorin - (1x)
# Support - (1x)
# Support-Mitarbeiter - (4x)
# Supporter - (1x)
# Supportmitarbeiter - (1x)
# System Architect - (2x)
# System Engeneer - (1x)
# Systemadministrator - (1x)
# Systemarchitekt - (1x)
# Systemintegrator - (1x)
# Teamleitung - (2x)
# Technical Lead - (1x)
# Techniker - (2x)
# Technische Leitung - (1x)
# Technischer Kundenservice - (1x)
# Technologie - (1x)
# Teil-Projektleiter - (2x)
# Teilprojektleiter - (8x)
# Teilprojektleitung - (20x)
# Trainer - (1x)
# Verantwortung Rollout - (1x)
# Verantwortung Support - (1x)
# externer Berater - (1x)
# stellvertretene Projektleitung - (1x)
#
#  ---------------------------------------------------------------------
#
# => Branchen:
# Anlagen- und Maschinenbau - (1x)
# Anlagenbau - (2x)
# Antriebs- und Fahrwerktechnik - (1x)
# Automobil - (1x)
# Automobil-Zulieferindustrie - (1x)
# Automobilindustrie - (2x)
# Automobilzulieferer - (3x)
# Automotive - (7x)
# Aviation - (1x)
# Bank - (1x)
# Banken - (3x)
# Banking - (1x)
# Bau - (2x)
# Baubranche - (1x)
# Bildung - (2x)
# Chemie - (7x)
# Chemische Industrie - (2x)
# Consumer Electronics - (1x)
# Data Science - (1x)
# Dienstleister - (1x)
# Dienstleistung - (1x)
# Dienstleistungen - (1x)
# Druck - (1x)
# Druckbranche - (1x)
# E-Commerce - (2x)
# Einzelhandel - (1x)
# Elektro - (1x)
# Elektroindustrie - (1x)
# Elektronik - (2x)
# Elektrotechnik - (1x)
# Energie - (6x)
# Energieversorger - (4x)
# Energieversorgung - (1x)
# Energiewirtschaft - (8x)
# Fast Moving Consumer Goods - (2x)
# Fertigungsindustrie - (2x)
# Finanzdienstleister - (1x)
# Finanzen - (1x)
# Flughafen-Betrieb - (1x)
# Flugzeughersteller - (1x)
# Forschung - (1x)
# GKV-Dienstleistungen - (1x)
# Gebäude-Management - (2x)
# Gesundheitswesen - (1x)
# Großhandel - (2x)
# Handel - (2x)
# Health Care - (2x)
# Hochschulen - (1x)
# Holz- und Kunststoffindustrie - (1x)
# IT - (1x)
# IT Dienstleistung - (1x)
# IT-Dienstleistungen - (1x)
# IT-Service - (1x)
# Industrie - (4x)
# Industrielle Dichtungstechnik - (1x)
# Industrielle Produktionsbetriebe - (1x)
# Informationstechnik - (2x)
# KFZ-Zulieferindustrie - (2x)
# Konsumgüter - (8x)
# Konsumgüter- und Nahrungsmittelindustrie - (1x)
# Konsumgüterindustrie - (1x)
# Kosmetik - (1x)
# Krankenkasse - (1x)
# Krankenversicherung - (2x)
# Kunststoffe - (1x)
# Lebensmittelindustrie - (2x)
# Lkw-Umbau - (1x)
# Logistik - (6x)
# Logistikbereich - (1x)
# Luftfahrtunternehmen - (1x)
# Maschinenbau - (2x)
# Materialwirtschaft - (5x)
# Medien - (4x)
# Medienbranche - (1x)
# Medizin-Zulieferindustrie - (1x)
# Medizintechnik - (2x)
# Meldungswesen - (1x)
# Mess- und Regeltechnik - (1x)
# Metall - (4x)
# Metall- und Elektroindustrie - (1x)
# Metallhalbzeug Fertigung - (4x)
# Metallindustrie - (4x)
# Mischkonzern - (2x)
# Mitarbeiterführung - (1x)
# Möbelindustrie - (2x)
# Nahrungs- und Genussmittel - (1x)
# Nahrungsmittel - (3x)
# Papier & Verpackung - (2x)
# Papier - (1x)
# Pharma - (13x)
# Pharmabereich - (1x)
# Pharmazeutische Industrie - (4x)
# Polymer-Lösungen - (1x)
# Predictive Planning - (1x)
# Produktion - (1x)
# Produktionsbetriebe - (1x)
# Produktsoftwareumfeld - (1x)
# Renten-Versicherung - (8x)
# Retail - (9x)
# Rohstoffe - (1x)
# Rollenmanagement - (1x)
# Rüstungsindustrie - (1x)
# SAP Beratung - (1x)
# Schiffbau - (5x)
# Schmierstoffe - (1x)
# Schneidanlagen - (1x)
# Sicherheit - (1x)
# Software-Hersteller - (1x)
# Sozialhilfe - (1x)
# Sozialversicherungen - (1x)
# Spiele - (1x)
# Spieles - (1x)
# Stahlindustrie - (3x)
# Stammdatenpflege - (1x)
# Telekommunikation - (6x)
# Tourismus - (5x)
# Transport - (1x)
# Transportmanagement - (1x)
# Urlaubausgleichs- und Zusatzversorgungskasse des Baugewerbes - (1x)
# Utilities - (1x)
# Veredlung - (1x)
# Verlag - (1x)
# Verlagswesen - (2x)
# Vermögensberatung - (1x)
# Verpackung - (3x)
# Verpackungsindustrie - (1x)
# Versicherung - (1x)
# Versicherungen - (1x)
# Vertrieb - (2x)
# Walzwerksfertigung - (1x)
# Werbebranche - (1x)
# Wärmetauscher - (2x)
# Zahlungsverkehrsanbieter - (1x)
# Zahlungsverkehrssysteme - (1x)
# Zellulose- und Papierprodukte - (1x)
# Zulieferer - (1x)
# Zusatzversorgungskasse - (9x)
# chemischen Industrie - (1x)
# mittelständische Industriebetriebe - (1x)
# verarbeitende Industrie - (1x)
# Öffentliche Verwaltung - (9x)
# Öffentlicher Sektor - (2x)
